# %% [markdown]
# ## Analyzing and Visualizing Census Rent Data
#
# See the data and map in action at .
#
# I loaded and geocoded the 2014 ACS 1-year median contract rent data in this notebook. Now, it's time to merge this data with the 2010 ACS rents and the 2010/2014 population data. The next steps are to analyze it, visualize it, map it, and then save it to GeoJSON so we can create an interactive web map using Leaflet.

# %%
# Install GeoPandas if not already installed
# !pip install geopandas

# Import necessary libraries for data manipulation and analysis
import pandas as pd  # For data manipulation and analysis
import numpy as np  # For numerical operations

# Import statistical models library
import statsmodels.api as sm  # For statistical modeling and hypothesis testing

# Import Matplotlib for plotting and visualization
import matplotlib.font_manager as fm  # For managing fonts
import matplotlib.pyplot as plt  # For creating plots and visualizations
import matplotlib.cm as cm  # For managing colormap options in plots

# Import Basemap for geographical plotting
from mpl_toolkits.basemap import Basemap  # For creating maps and plotting geographic data

# Import GeoPandas for handling geospatial data
from geopandas import GeoDataFrame  # For creating and working with geospatial dataframes

# Import Shapely for geometric operations
from shapely.geometry import Point  # For creating point geometries

# Enable inline plotting for Jupyter notebooks
# %matplotlib inline  # Ensures that plots are displayed inline within Jupyter notebooks
# Out:
# Requirement already satisfied: geopandas in c:\users\men_l\anaconda3\lib\site-packages (1.0.1)
# Requirement already satisfied: numpy>=1.22 in c:\users\men_l\anaconda3\lib\site-packages (from geopandas) (1.26.4)
# Requirement already satisfied: pyogrio>=0.7.2 in c:\users\men_l\anaconda3\lib\site-packages (from geopandas) (0.10.0)
# Requirement already satisfied: packaging in c:\users\men_l\anaconda3\lib\site-packages (from geopandas) (23.2)
# Requirement already satisfied: pandas>=1.4.0 in c:\users\men_l\anaconda3\lib\site-packages (from geopandas) (2.2.2)
# Requirement already satisfied: pyproj>=3.3.0 in c:\users\men_l\anaconda3\lib\site-packages (from geopandas) (3.6.1)
# Requirement already satisfied: shapely>=2.0.0 in c:\users\men_l\anaconda3\lib\site-packages (from geopandas) (2.0.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\men_l\anaconda3\lib\site-packages (from pandas>=1.4.0->geopandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\men_l\anaconda3\lib\site-packages (from pandas>=1.4.0->geopandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\men_l\anaconda3\lib\site-packages (from pandas>=1.4.0->geopandas) (2023.3)
# Requirement already satisfied: certifi in c:\users\men_l\anaconda3\lib\site-packages (from pyogrio>=0.7.2->geopandas) (2024.6.2)
# Requirement already satisfied: six>=1.5 in c:\users\men_l\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.4.0->geopandas) (1.16.0)
# UsageError: unrecognized arguments: # Ensures that plots are displayed inline within Jupyter notebooks

# %%
# Define the font family to use for plots
font_family = 'Myriad Pro'

# Define the font properties for the plot title
# family: the font family
# style: the font style (e.g., 'normal', 'italic')
# size: the font size
# weight: the weight of the font (e.g., 'normal', 'bold')
# stretch: the stretch of the font (e.g., 'normal', 'condensed')
title_font = fm.FontProperties(family=font_family, style='normal', size=18, weight='normal', stretch='normal')

# Define the font properties for the plot labels
label_font = fm.FontProperties(family=font_family, style='normal', size=16, weight='normal', stretch='normal')

# Define the font properties for the plot ticks
ticks_font = fm.FontProperties(family=font_family, style='normal', size=14, weight='normal', stretch='normal')

# %%
# Load the 2014 geolocated rent data from a CSV file
# 'data/rent_latlong.csv' should be the path to your CSV file containing the rent data
rent14 = pd.read_csv('data/rent_latlong.csv')

# Rename the column 'geo_id2' to 'geo_id_14' for clarity and consistency
rent14 = rent14.rename(columns={'geo_id2': 'geo_id_14'})

# Select relevant columns for analysis: 'geo_id_14', 'msa_name', 'city_state',
# 'median_contract_rent', 'latitude', and 'longitude'
rent14 = rent14[['geo_id_14', 'msa_name', 'city_state', 'median_contract_rent', 'latitude', 'longitude']]

# Display the first few rows of the dataframe to verify the changes
print(rent14.head())
# Out:
#    geo_id_14                   msa_name      city_state  median_contract_rent  \
# 0      10140    Aberdeen, WA Micro Area    Aberdeen, WA                   626
# 1      10180     Abilene, TX Metro Area     Abilene, TX                   613
# 2      10300      Adrian, MI Micro Area      Adrian, MI                   556
# 3      10420       Akron, OH Metro Area       Akron, OH                   627
# 4      10460  Alamogordo, NM Micro Area  Alamogordo, NM                   700
#
#     latitude   longitude
# 0  46.975371 -123.815722
# 1  32.448736  -99.733144
# 2  41.897547  -84.037166
# 3  41.081445  -81.519005
# 4  32.899532 -105.960265

# %%
# Load the 2010 rent data from the specified CSV file into a DataFrame
rent10 = pd.read_csv('data/ACS_10_1YR_B25058_metro_micro/ACS_10_1YR_B25058.csv')

# Rename columns to more readable names
rent10 = rent10.rename(columns={
    'GEO.id': 'geo_id',               # Original geographic ID
    'GEO.id2': 'geo_id_10',           # Secondary geographic ID (likely a more specific identifier)
    'GEO.display-label': 'msa_name',  # Metropolitan Statistical Area (MSA) name
    'HD01_VD01': 'median_rent_10',    # Median rent for 2010
    'HD02_VD01': 'margin_error'       # Margin of error for the median rent estimate
})

# Select only the columns 'geo_id_10' and 'median_rent_10' for further analysis
rent10 = rent10[['geo_id_10', 'median_rent_10']]

# Display the first few rows of the DataFrame to verify the changes
print(rent10.head())
# Out:
#    geo_id_10  median_rent_10
# 0      10140             562
# 1      10180             554
# 2      10300             537
# 3      10420             579
# 4      10500             477

# %% [markdown]
# ### Merging 2010 and 2014 ACS Rent Data
#
# To merge the 2010 and 2014 ACS rent data effectively, follow these steps:
#
# 1. **Load the Data**: Read the 2010 and 2014 ACS rent data into pandas DataFrames.
# 2. **Rename Columns**: Ensure both DataFrames have consistent column names to facilitate merging.
# 3. **Create a Mapping Dictionary**: Map 2014 codes to 2010 codes for areas that have changed.
#    - Some areas have changed names or codes between 2010 and 2014, and for these, you will need to create a mapping dictionary.
# 4. **Apply the Mapping**: Use the mapping dictionary to update the 2014 codes to their corresponding 2010 codes.
# 5. **Select Relevant Columns**: Choose the necessary columns from both DataFrames for comparison.
# 6. **Merge the DataFrames**: Combine the data on the 2010 geo_id using an inner join to retain only areas with data in both years.
# 7. **Handle Unmatched Data**: Ignore areas that are new in 2014 or were dropped since 2010, as they cannot be compared without data from both years.
#
# Following these steps ensures that your merged dataset is accurate and includes only comparable rent data from both years, allowing for effective analysis.

# %%
# Import pandas library
import pandas as pd

# Define a dictionary to map 2014 codes to 2010 codes for areas that changed
codes_14_10 = {  # Format: 2014_code:2010_code
    14010: 14060,  # Bloomington, IL
    15680: 30500,  # Lexington Park, MD
    16060: 32060,  # Marion, IL
    17200: 30100,  # Lebanon, NH
    25840: 37820,  # Pendleton
    26090: 26100,  # Holland
    29200: 29140,  # Lafayette
    38240: 43860,  # Pinehurst
    41400: 20620,  # Salem, OH
    48260: 44600,  # Weirton
    49220: 32270,  # Wisconsin Rapids
    31080: 31100,  # Los Angeles
    42200: 42060,  # Santa Barbara
    46520: 26180,  # Honolulu
    48260: 44600   # Steubenville
}

# Create a new column 'geo_id_10' in the 2014 DataFrame to hold the corresponding 2010 code
# The lambda function maps each 2014 geo_id to its corresponding 2010 geo_id using the 'codes_14_10' dictionary
# If a 2014 geo_id is not in the dictionary (i.e., the area is new or dropped), it retains the original 2014 geo_id
rent14['geo_id_10'] = rent14['geo_id_14'].map(lambda x: codes_14_10[x] if x in codes_14_10.keys() else x)

# %%
# Import pandas library
import pandas as pd

# Merge the 2014 and 2010 rent datasets on the 'geo_id_10' column
# 'rent14' contains the 2014 rent data with the 'geo_id_10' column mapped to 2010 codes
# 'rent10' contains the 2010 rent data
rent = pd.merge(rent14, rent10, on='geo_id_10')

# Display the first few rows of the merged DataFrame to verify the merge
rent.head()
# Out:
#    geo_id_14                 msa_name    city_state  median_contract_rent  \
# 0      10140  Aberdeen, WA Micro Area  Aberdeen, WA                   626
# 1      10180   Abilene, TX Metro Area   Abilene, TX                   613
# 2      10300    Adrian, MI Micro Area    Adrian, MI                   556
# 3      10420     Akron, OH Metro Area     Akron, OH                   627
# 4      10500    Albany, GA Metro Area    Albany, GA                   480
#
#     latitude   longitude  geo_id_10  median_rent_10
# 0  46.975371 -123.815722      10140             562
# 1  32.448736  -99.733144      10180             554
# 2  41.897547  -84.037166      10300             537
# 3  41.081445  -81.519005      10420             579
# 4  31.578507  -84.155741      10500             477

# %%
# Calculate the percentage change in median rent from 2010 to 2014
# Create a new column 'rent_change_pct' to store the percentage change
rent['rent_change_pct'] = (rent['median_contract_rent'] / rent['median_rent_10'] - 1) * 100

# Sort the DataFrame by the 'rent_change_pct' column to see the changes
# Display the first few rows of the sorted DataFrame, showing the 'msa_name' and 'rent_change_pct'
rent.sort_values(by='rent_change_pct')[['msa_name', 'rent_change_pct']].head()
# Out:
#                                msa_name  rent_change_pct
# 414               Seneca, SC Micro Area       -14.417745
# 413              Sebring, FL Metro Area       -11.992945
# 69           Carson City, NV Metro Area        -9.015257
# 464             Valdosta, GA Metro Area        -7.992895
# 442  Talladega-Sylacauga, AL Micro Area        -7.049608

# %% [markdown]
# ### Loading the Population Data
#
# Now, let's load the population data. This file contains:
# - 2014 population estimates
# - 2010 population values from the census
#
# By importing this data, you can analyze the population changes over these years.

# %%
# Import pandas library
import pandas as pd

# Load the population data from the specified CSV file into a DataFrame
# 'encoding=utf-8' ensures that the data is read correctly, especially if it contains special characters
pops = pd.read_csv('data/PEP_2014_PEPANNRES/PEP_2014_PEPANNRES.csv', encoding='utf-8')

# Rename columns for better readability and consistency
# 'GEO.id2' is renamed to 'geo_id_14' to match the 2014 geographic ID
# 'rescen42010' is renamed to 'pop_10' representing the population in 2010
# 'respop72014' is renamed to 'pop_est_14' representing the estimated population in 2014
pops = pops.rename(columns={
    'GEO.id2': 'geo_id_14',  # 2014 geographic ID
    'rescen42010': 'pop_10',  # Population in 2010
    'respop72014': 'pop_est_14'  # Estimated population in 2014
})

# Select only the necessary columns for analysis
# 'geo_id_14' for the 2014 geographic ID
# 'pop_10' for the 2010 population
# 'pop_est_14' for the 2014 estimated population
pops = pops[['geo_id_14', 'pop_10', 'pop_est_14']]

# Display the first few rows of the DataFrame to verify the changes
# This helps ensure the data has been loaded and processed correctly
pops.head()
# Out:
#    geo_id_14  pop_10  pop_est_14
# 0      10100   40602       42391
# 1      10140   72797       70818
# 2      10180  165252      168592
# 3      10220   37492       38005
# 4      10300   99892       99047

# %%
# Merge the 'rent' DataFrame with the 'pops' DataFrame on the 'geo_id_14' column
# This combines the datasets where the 'geo_id_14' in 'rent' matches 'geo_id_14' in 'pops'
df = pd.merge(rent, pops, on='geo_id_14')

# Display the first few rows of the merged DataFrame
# This is useful for verifying the merged result and checking if the data aligns correctly
df.head()
# Out:
#    geo_id_14                 msa_name    city_state  median_contract_rent  \
# 0      10140  Aberdeen, WA Micro Area  Aberdeen, WA                   626
# 1      10180   Abilene, TX Metro Area   Abilene, TX                   613
# 2      10300    Adrian, MI Micro Area    Adrian, MI                   556
# 3      10420     Akron, OH Metro Area     Akron, OH                   627
# 4      10500    Albany, GA Metro Area    Albany, GA                   480
#
#     latitude   longitude  geo_id_10  median_rent_10  rent_change_pct  pop_10  \
# 0  46.975371 -123.815722      10140             562        11.387900   72797
# 1  32.448736  -99.733144      10180             554        10.649819  165252
# 2  41.897547  -84.037166      10300             537         3.538175   99892
# 3  41.081445  -81.519005      10420             579         8.290155  703200
# 4  31.578507  -84.155741      10500             477         0.628931  157308
#
#    pop_est_14
# 0       70818
# 1      168592
# 2       99047
# 3      703825
# 4      154925

# %%
# Calculate the percentage change in population from 2010 to 2014
# Create a new column 'pop_change_pct' to store the percentage change
df['pop_change_pct'] = (df['pop_est_14'] / df['pop_10'] - 1) * 100

# Sort the DataFrame by the 'pop_change_pct' column to see the changes
# Display the first few rows of the sorted DataFrame, showing the 'msa_name' and 'pop_change_pct'
df.sort_values(by='pop_change_pct')[['msa_name', 'pop_change_pct']].head()
# Out:
#                           msa_name  pop_change_pct
# 348      Pine Bluff, AR Metro Area       -5.527738
# 142      Farmington, NM Metro Area       -4.812986
# 377  Roanoke Rapids, NC Micro Area       -4.371663
# 214       Johnstown, PA Metro Area       -4.139088
# 277    Martinsville, VA Micro Area       -3.207203

# %% [markdown]
# ### Explore relationships in the data with some scatterplots

# %%
# Create a scatter plot to visualize the relationship between population change and rent change
# 'pop_change_pct' is the x-axis and 'rent_change_pct' is the y-axis
df.plot(kind='scatter', x='pop_change_pct', y='rent_change_pct')

# Add labels and a title to the plot for better understanding
plt.xlabel('Population Change (%)')
plt.ylabel('Rent Change (%)')
plt.title('Percentage Change in Rent vs. Percentage Change in Population')

# Display the plot
plt.show()

# %%
# Create a scatter plot to visualize the relationship between 2010 population and 2014 population estimates
# 'pop_10' is the x-axis and 'pop_est_14' is the y-axis
df.plot(kind='scatter', x='pop_10', y='pop_est_14')

# Add labels and a title to the plot for better understanding
plt.xlabel('2010 Population')
plt.ylabel('2014 Population Estimate')
plt.title('2014 Population Estimate vs. 2010 Population')

# Display the plot
plt.show()

# %%
# Create a scatter plot
df.plot(kind='scatter', x='median_rent_10', y='median_contract_rent')

# Customize plot with labels and title for better understanding
plt.xlabel('2010 Median Rent ($)')  # Label for x-axis
plt.ylabel('2014 Median Contract Rent ($)')  # Label for y-axis
plt.title('Comparison of 2010 vs 2014 Median Rent')  # Title of the plot
plt.grid(True)  # Display grid lines for easier visualization
plt.show()  # Display the plot

# %%
# Create a scatter plot
df.plot(kind='scatter', x='pop_est_14', y='median_contract_rent', xlim=[0, 1000000])

# Customize plot with labels and title for better understanding
plt.xlabel('2014 Population Estimate')  # Label for x-axis
plt.ylabel('2014 Median Contract Rent ($)')  # Label for y-axis
plt.title('Comparison of 2014 Population vs 2014 Median Rent')  # Title of the plot
plt.grid(True)  # Display grid lines for easier visualization
plt.show()  # Display the plot

# %%
# Create a scatter plot
df.plot(kind='scatter', x='pop_10', y='median_rent_10', xlim=[0, 1000000])

# Customize plot with labels and title for better understanding
plt.xlabel('2010 Population Estimate')  # Label for x-axis
plt.ylabel('2010 Median Rent ($)')  # Label for y-axis
plt.title('Comparison of 2010 Population vs 2010 Median Rent')  # Title of the plot
plt.grid(True)  # Display grid lines for easier visualization
plt.show()  # Display the plot

# %%
# Create a scatter plot
df.plot(kind='scatter', x='rent_change_pct', y='median_contract_rent')

# Customize plot with labels and title for better understanding
plt.xlabel('Percent Change in Rent (2010-2014)')  # Label for x-axis
plt.ylabel('2014 Median Contract Rent ($)')  # Label for y-axis
plt.title('Comparison of 2014 Median Rent vs Percent Change in Rent (2010-2014)')  # Title of the plot
plt.grid(True)  # Display grid lines for easier visualization
plt.show()  # Display the plot

# %%
# Plot 2014 median rent vs 2010 median rent
fig, ax = plt.subplots()
fig.set_size_inches(7, 7)  # Set the size of the figure
axis_min = 0  # Minimum value for the axes
axis_max = 1800  # Maximum value for the axes
    
# Regress 2014 rent on 2010 rent
X = df['median_rent_10']  # Independent variable (2010 median rent)
Y = df['median_contract_rent']  # Dependent variable (2014 median rent)
results = sm.OLS(Y, sm.add_constant(X)).fit()  # Perform ordinary least squares (OLS) regression

# Calculate estimated y values for the regression line
X_line = X.copy()  # Copy the independent variable data
X_line.loc[axis_min] = axis_min  # Add minimum value to the data
X_line.loc[axis_max] = axis_max  # Add maximum value to the data
Y_est = X_line * results.params[1] + results.params[0]  # Calculate estimated y values using regression parameters

# Draw points, regression line, and line of 1:1 linear relationship
# ax.plot([axis_min, axis_max], [axis_min, axis_max], 'k-', color='k', alpha=0.3, linewidth=2)  # Line of 1:1 relationship (commented out)
ax.plot(X_line, Y_est, c='#333333', alpha=0.4, linewidth=2)  # Plot the regression line
ax.scatter(X, Y, c='m', edgecolor='#333333', alpha=0.4, s=50)  # Scatter plot of the data points

ax.set_xlim([axis_min, axis_max])  # Set x-axis limits
ax.set_ylim([axis_min, axis_max])  # Set y-axis limits

# Customize plot with labels and title
ax.set_title('2014 vs 2010 Median Rent, by Metro Area', fontproperties=title_font)  # Title of the plot
ax.set_xlabel('2010 Median Rent (USD)', fontproperties=label_font)  # Label for x-axis
ax.set_ylabel('2014 Median Rent (USD)', fontproperties=label_font)  # Label for y-axis

fig.tight_layout()  # Adjust layout to fit elements properly
fig.savefig('images/scatter-rent-change-2010-2014.png', dpi=300)  # Save the plot as an image
plt.show()  # Display the plot
# Out:
# C:\Users\men_l\AppData\Local\Temp\ipykernel_34468\1363717500.py:16: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   Y_est = X_line * results.params[1] + results.params[0]  # Calculate estimated y values using regression parameters
# findfont: Font family 'Myriad Pro' not found.
# findfont: Font family 'Myriad Pro' not found.
# findfont: Font family 'Myriad Pro' not found.
# findfont: Font family 'Myriad Pro' not found.
# findfont: Font family 'Myriad Pro' not found.
# findfont: Font family 'Myriad Pro' not found.
# findfont: Font family 'Myriad Pro' not found.
# findfont: Font family 'Myriad Pro' not found.
# findfont: Font family 'Myriad Pro' not found.
# findfont: Font family 'Myriad Pro' not found.
# findfont: Font family 'Myriad Pro' not found.
# findfont: Font family 'Myriad Pro' not found.
# findfont: Font family 'Myriad Pro' not found.
# findfont: Font family 'Myriad Pro' not found.
# findfont: Font family 'Myriad Pro' not found.
# findfont: Font family 'Myriad Pro' not found.
# findfont: Font family 'Myriad Pro' not found.
# findfont: Font family 'Myriad Pro' not found.
# findfont: Font family 'Myriad Pro' not found.
# findfont: Font family 'Myriad Pro' not found.
# findfont: Font family 'Myriad Pro' not found.
# findfont: Font family 'Myriad Pro' not found.
# findfont: Font family 'Myriad Pro' not found.
# findfont: Font family 'Myriad Pro' not found.
# findfont: Font family 'Myriad Pro' not found.
# findfont: Font family 'Myriad Pro' not found.

# %%
# Plot percent change in median rent vs percent change in population, 2010-2014
fig, ax = plt.subplots()  # Create a figure and a set of subplots
fig.set_size_inches(7, 7)  # Set the size of the figure to 7x7 inches

# Regress rent change rate on population change rate
X = df['pop_change_pct']  # Independent variable: percent change in population
Y = df['rent_change_pct']  # Dependent variable: percent change in median rent
results = sm.OLS(Y, sm.add_constant(X)).fit()  # Perform ordinary least squares (OLS) regression

# Calculate estimated y values for regression line
X_line = X.copy()  # Copy the independent variable data
X_line.loc[-10] = -10  # Add a point to ensure the line starts at -10 for better visualization
X_line.loc[30] = 30  # Add a point to ensure the line extends to 30 for better visualization
X_line = X_line.sort_index()  # Ensure X_line is sorted by index
Y_est = X_line * results.params[1] + results.params[0]  # Calculate estimated y values using regression parameters

# Draw points and regression line
# ax.plot(X_line, Y_est, c='#333333', alpha=0.4, linewidth=2)  # Uncomment to draw regression line
ax.scatter(X, Y, c='b', edgecolor='#333333', alpha=0.4, s=50)  # Scatter plot of the data points

# Set the limits for the axes
ax.set_xlim([-8, 25])  # Set limits for x-axis
ax.set_ylim([-20, 80])  # Set limits for y-axis

# Customize plot with labels and title
ax.set_title('Rent change vs Population change, by metro area', fontproperties=title_font)  # Title of the plot
ax.set_xlabel('Percent change in population, 2010 - 2014', fontproperties=label_font)  # Label for x-axis
ax.set_ylabel('Percent change in median rent, 2010 - 2014', fontproperties=label_font)  # Label for y-axis

fig.tight_layout()  # Adjust layout to fit elements properly

# Save the plot as an image
fig.savefig('images/scatter-rent-pop-change-2010-14.png', dpi=300)

plt.show()  # Display the plot
# Out:
# C:\Users\men_l\AppData\Local\Temp\ipykernel_34468\968808679.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   Y_est = X_line * results.params[1] + results.params[0]  # Calculate estimated y values using regression parameters
# findfont: Font family 'Myriad Pro' not found.
# findfont: Font family 'Myriad Pro' not found.
# findfont: Font family 'Myriad Pro' not found.
# findfont: Font family 'Myriad Pro' not found.
# findfont: Font family 'Myriad Pro' not found.
# findfont: Font family 'Myriad Pro' not found.
# findfont: Font family 'Myriad Pro' not found.
# findfont: Font family 'Myriad Pro' not found.
# findfont: Font family 'Myriad Pro' not found.
# findfont: Font family 'Myriad Pro' not found.
# findfont: Font family 'Myriad Pro' not found.
# findfont: Font family 'Myriad Pro' not found.
# findfont: Font family 'Myriad Pro' not found.
# findfont: Font family 'Myriad Pro' not found.
# findfont: Font family 'Myriad Pro' not found.
# findfont: Font family 'Myriad Pro' not found.
# findfont: Font family 'Myriad Pro' not found.
# findfont: Font family 'Myriad Pro' not found.
# findfont: Font family 'Myriad Pro' not found.
# findfont: Font family 'Myriad Pro' not found.
# findfont: Font family 'Myriad Pro' not found.
# findfont: Font family 'Myriad Pro' not found.
# findfont: Font family 'Myriad Pro' not found.
# findfont: Font family 'Myriad Pro' not found.
# findfont: Font family 'Myriad Pro' not found.
# findfont: Font family 'Myriad Pro' not found.

# %%
# Plot 2014 median rent vs 2014 population
fig, ax = plt.subplots()  # Create a figure and a set of subplots
fig.set_size_inches(7, 7)  # Set the size of the figure to 7x7 inches

# Regress rent on population (log-transformed)
X = np.log(df['pop_est_14'])  # Log-transform the population data for better linearity
Y = df['median_contract_rent']  # Median rent values
results = sm.OLS(Y, sm.add_constant(X)).fit()  # Perform ordinary least squares (OLS) regression

# Calculate estimated y values for regression line
X_line = X.copy()  # Copy the independent variable data
X_line.loc[0] = 0  # Add a point at log(1) = 0 for better visualization
X_line.loc[20] = 20  # Add a point at log(20) = approximately 3 for better visualization
X_line = X_line.sort_index()  # Ensure X_line is sorted by index
Y_est = X_line * results.params[1] + results.params[0]  # Calculate estimated y values using regression parameters

# Draw points and regression line
# Uncomment the line below if you want to draw the regression line
# ax.plot(X_line, Y_est, c='#333333', alpha=0.4, linewidth=2)  # Plot the regression line

# Scatter plot of the data points
ax.scatter(X, Y, c='g', edgecolor='#333333', alpha=0.4, s=50)

# Set the limits for the axes
ax.set_xlim([10, 18])  # Set limits for x-axis based on log-transformed population
ax.set_ylim([0, 2000])  # Set limits for y-axis based on median rent values

# Customize plot with labels and title
ax.set_title('Rent vs Population, by metro area', fontproperties=title_font)  # Title of the plot
ax.set_xlabel('2014 Population (log)', fontproperties=label_font)  # Label for x-axis
ax.set_ylabel('2014 Median Rent', fontproperties=label_font)  # Label for y-axis

# Adjust layout to fit elements properly
fig.tight_layout()

# Save the plot as an image
fig.savefig('images/scatter-rent-pop-log-2010-14.png', dpi=300)

# Display the plot
plt.show()
# Out:
# C:\Users\men_l\AppData\Local\Temp\ipykernel_34468\3535797332.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   Y_est = X_line * results.params[1] + results.params[0]  # Calculate estimated y values using regression parameters
# findfont: Font family 'Myriad Pro' not found.
# findfont: Font family 'Myriad Pro' not found.
# findfont: Font family 'Myriad Pro' not found.
# findfont: Font family 'Myriad Pro' not found.
# findfont: Font family 'Myriad Pro' not found.
# findfont: Font family 'Myriad Pro' not found.
# findfont: Font family 'Myriad Pro' not found.
# findfont: Font family 'Myriad Pro' not found.
# findfont: Font family 'Myriad Pro' not found.
# findfont: Font family 'Myriad Pro' not found.
# findfont: Font family 'Myriad Pro' not found.
# findfont: Font family 'Myriad Pro' not found.
# findfont: Font family 'Myriad Pro' not found.
# findfont: Font family 'Myriad Pro' not found.
# findfont: Font family 'Myriad Pro' not found.
# findfont: Font family 'Myriad Pro' not found.
# findfont: Font family 'Myriad Pro' not found.
# findfont: Font family 'Myriad Pro' not found.
# findfont: Font family 'Myriad Pro' not found.
# findfont: Font family 'Myriad Pro' not found.
# findfont: Font family 'Myriad Pro' not found.
# findfont: Font family 'Myriad Pro' not found.
# findfont: Font family 'Myriad Pro' not found.
# findfont: Font family 'Myriad Pro' not found.
# findfont: Font family 'Myriad Pro' not found.
# findfont: Font family 'Myriad Pro' not found.

# %%
# Number of bins to divide the data into (quantiles)
num_bins = 5
# Labels for the bins, ranging from 0 to num_bins-1
bin_labels = range(num_bins)

# Create categorical variable for median contract rent by dividing into quantiles
df['rent_cat'] = pd.qcut(x=df['median_contract_rent'], q=num_bins, labels=bin_labels)
# Create categorical variable for rent change percentage by dividing into quantiles
df['rent_change_cat'] = pd.qcut(x=df['rent_change_pct'], q=num_bins, labels=bin_labels)
# Create categorical variable for population change percentage by dividing into quantiles
df['pop_change_cat'] = pd.qcut(x=df['pop_change_pct'], q=num_bins, labels=bin_labels)

# Display the first few rows of the DataFrame to see the new categorical variables
df[['msa_name', 'rent_cat', 'rent_change_cat', 'pop_change_cat']].head()
# Out:
#                   msa_name rent_cat rent_change_cat pop_change_cat
# 0  Aberdeen, WA Micro Area        2               3              0
# 1   Abilene, TX Metro Area        2               3              2
# 2    Adrian, MI Micro Area        1               0              0
# 3     Akron, OH Metro Area        2               2              1
# 4    Albany, GA Metro Area        0               0              0

# %%
import matplotlib.cm as cm

# Define basemap colors
land_color = '#f5f5f3'       # Color for land areas
water_color = '#cdd2d4'      # Color for water bodies
coastline_color = '#666666'  # Color for coastlines
border_color = '#999999'     # Color for borders

# Number of bins to divide the data into (quantiles)
num_bins = 5

# Get colors between blue and red, one for each bin
color_map = cm.get_cmap('brg')  # Get the colormap 'brg' which contains blue, red, and green
increments = [x * .6 / float(num_bins) for x in range(num_bins)]  
# List of increments between 0 and 0.6 for dividing the color map evenly into bins
# x * .6 / float(num_bins): This calculates the increment value for each bin

color_list = color_map(increments).tolist()  # Get the colors for each increment and convert to a list
# color_map(increments): This gets the RGBA colors from the colormap based on the increments
# .tolist(): Convert the RGBA colors to a list

# Output color list for verification
print(color_list)
# Out:
# [[0.0, 0.0, 1.0, 1.0], [0.23529411764705882, 0.0, 0.7647058823529411, 1.0], [0.4784313725490196, 0.0, 0.5215686274509804, 1.0], [0.7215686274509804, 0.0, 0.2784313725490196, 1.0], [0.9568627450980391, 0.0, 0.04313725490196085, 1.0]]
# C:\Users\men_l\AppData\Local\Temp\ipykernel_34468\4021054296.py:13: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   color_map = cm.get_cmap('brg')  # Get the colormap 'brg' which contains blue, red, and green

# %%
# Define the function to draw the basemap and scatterplot the point data
def draw_map(cat, title):
    # Specify map width and height with approximate US dimensions
    map_width_m = 5000 * 1000  # Width of the map in meters (5000 km)
    map_height_m = 3500 * 1000  # Height of the map in meters (3500 km)
    plt.figure(figsize=[10, 10 * (map_height_m / float(map_width_m))])  # Make plot the same height:width ratio

    # Albers Conical Equal Area projection for US
    m = Basemap(
        ellps='WGS84',
        projection='aea',
        lat_1=33,
        lat_2=45,
        lon_0=-98.4,
        lat_0=39,
        width=map_width_m,
        height=map_height_m,
        resolution='l',
        area_thresh=10000,
        fix_aspect=False
    )

    # Draw geographic boundaries
    m.drawcoastlines(color=coastline_color)  # Draw coastlines
    m.drawcountries(color=border_color)  # Draw country borders
    m.drawstates(color=border_color)  # Draw state borders
    m.fillcontinents(color=land_color, lake_color=water_color)  # Fill land and water areas
    m.drawmapboundary(fill_color=water_color)  # Draw map boundary with water color

    # Project and plot our lat-long data with each bin getting its own color
    for color, n in zip(color_list, range(num_bins)):
        subset = df[df[cat] == n]  # Subset data for the current bin
        x, y = m(np.array(subset['longitude']), np.array(subset['latitude']))  # Project latitude and longitude
        m.scatter(x=x, y=y, s=200, color=color, edgecolor='#555555', alpha=0.7, zorder=10)  # Scatter plot the points

    # Finalize and save the plot
    fig = plt.gcf()  # Get the current figure
    fig.tight_layout()  # Adjust the layout to fit elements properly
    fig.savefig('images/{}.png'.format(title), dpi=300)  # Save the plot as an image
    plt.show()  # Display the plot

# Example usage
# Define some example variables and DataFrame (df) for illustration
import pandas as pd

# Basemap colors
land_color = '#f5f5f3'
water_color = '#cdd2d4'
coastline_color = '#666666'
border_color = '#999999'

# Number of bins to divide the data into (quantiles)
num_bins = 5

# Get colors between blue and red, one for each bin
import matplotlib.cm as cm

color_map = cm.get_cmap('brg')  # Get the colormap 'brg' which contains blue, red, and green
increments = [x * .6 / float(num_bins) for x in range(num_bins)]  # List of increments between 0 and 0.6 for dividing the color map evenly into bins
color_list = color_map(increments).tolist()  # Get the colors for each increment and convert to a list

# Call the function
draw_map(cat='rent_cat', title='median_rent_msa')
# Out:
# C:\Users\men_l\AppData\Local\Temp\ipykernel_34468\4043108587.py:58: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   color_map = cm.get_cmap('brg')  # Get the colormap 'brg' which contains blue, red, and green

# %%
# Function call to draw the map of percentage change in median rent per metro/micro area,
# colored by nationwide quintile.
# 'rent_change_cat' is the categorical variable for rent change percentiles.
# 'rent_change_msa' is the title for the saved plot image.
draw_map('rent_change_cat', 'rent_change_msa')

# %%
# Function call to draw the map of percentage change in population per metro/micro area,
# colored by nationwide quintile.
# 'pop_change_cat' is the categorical variable for population change percentiles.
# 'pop_change_msa' is the title for the saved plot image.
draw_map('pop_change_cat', 'pop_change_msa')

# %% [markdown]
# ### Format everything neatly for display on an interactive web map.

# %%
# Function to format percentages nicely for display
def format_pct(pct):
    # Round the percentage to one decimal place
    pct = round(pct, 1)
    # Add a '+' prefix if the percentage is positive
    prefix = '+' if pct > 0 else ''
    # Return the formatted string with the prefix and the percentage
    return '{}{}%'.format(prefix, pct)

# Apply the format_pct function to the 'rent_change_pct' and 'pop_change_pct' columns
df['rent_change_pct_s'] = df['rent_change_pct'].map(format_pct)
df['pop_change_pct_s'] = df['pop_change_pct'].map(format_pct)

# Display the first few rows of the DataFrame to verify the changes
print(df[['pop_change_pct_s', 'rent_change_pct_s']].head())
# Out:
#   pop_change_pct_s rent_change_pct_s
# 0            -2.7%            +11.4%
# 1            +2.0%            +10.6%
# 2            -0.8%             +3.5%
# 3            +0.1%             +8.3%
# 4            -1.5%             +0.6%

# %%
# Function to format population numbers nicely for display
def format_pop(pop):
    # Format the population number with commas as thousand separators
    return '{:,}'.format(pop)

# Apply the format_pop function to the 'pop_10' and 'pop_est_14' columns
df['pop_10_s'] = df['pop_10'].map(format_pop)
df['pop_est_14_s'] = df['pop_est_14'].map(format_pop)

# Display the first few rows of the DataFrame to verify the changes
print(df[['pop_10_s', 'pop_est_14_s']].head())
# Out:
#   pop_10_s pop_est_14_s
# 0   72,797       70,818
# 1  165,252      168,592
# 2   99,892       99,047
# 3  703,200      703,825
# 4  157,308      154,925

# %%
# Function to format rent values nicely for display
def format_rent(rent):
    # Format the rent value with commas as thousand separators and a dollar sign
    return '${:,}'.format(rent)

# Assuming df is your DataFrame with the relevant columns

# Apply the format_rent function to the 'median_contract_rent' column
# Create a new column 'median_contract_rent_s' with the formatted rent values
df['median_contract_rent_s'] = df['median_contract_rent'].map(format_rent)

# Apply the format_rent function to the 'median_rent_10' column
# Create a new column 'median_rent_10_s' with the formatted rent values
df['median_rent_10_s'] = df['median_rent_10'].map(format_rent)

# Display the first few rows of the DataFrame sorted by 'median_contract_rent_s' to verify the changes
# This will show the nicely formatted rent values
sorted_df = df[['median_contract_rent_s', 'median_rent_10_s']].sort_values(by='median_contract_rent_s')

# Display the result
print(sorted_df.head())
# Out:
#     median_contract_rent_s median_rent_10_s
# 375                 $1,007             $952
# 284                 $1,011             $940
# 64                  $1,041           $1,025
# 411                 $1,046             $903
# 287                 $1,075             $660

# %% [markdown]
# ### Display some descriptive tables.

# %%
# Display the column names print
df.columns
# Out:
# Index(['geo_id_14', 'msa_name', 'city_state', 'median_contract_rent',
#        'latitude', 'longitude', 'geo_id_10', 'median_rent_10',
#        'rent_change_pct', 'pop_10', 'pop_est_14', 'pop_change_pct', 'rent_cat',
#        'rent_change_cat', 'pop_change_cat', 'rent_change_pct_s',
#        'pop_change_pct_s', 'pop_10_s', 'pop_est_14_s',
#        'median_contract_rent_s', 'median_rent_10_s'],
#       dtype='object')

# %%
# Assuming df is your DataFrame with the relevant columns

# Create a new DataFrame with selected columns and nice column names for publication
# This helps in presenting the data more clearly and professionally

# Select relevant columns
ds = df[['median_contract_rent_s', 'median_contract_rent', 'city_state', 'pop_change_pct', 'pop_change_pct_s',
         'rent_change_pct', 'rent_change_pct_s', 'pop_est_14']]

# Rename columns for better readability and presentation
ds = ds.rename(columns={
    'median_contract_rent_s': '2014 Median Rent',  # Renamed for clarity
    'city_state': 'Metro Area',                    # Renamed for clarity
    'pop_est_14': '2014 Population',               # Renamed for clarity
    'rent_change_pct_s': 'Change since 2010',      # Renamed for clarity
    'pop_change_pct_s': 'Pop. Change'              # Renamed for clarity
})

# Define the order of columns for the final display
cols = ['Metro Area', '2014 Median Rent', 'Change since 2010']

# %%
# Step 1: Sort the DataFrame `ds` to get metros with the highest median rents
# We sort by the 'median_contract_rent' column in descending order to have the highest rents at the top
# `ascending=False` ensures the sort is in descending order
sorted_ds = ds.sort_values(by='median_contract_rent', ascending=False)

# Step 2: Select only the columns defined in `cols` for the final display
# This ensures that we only keep the columns we are interested in displaying
metros = sorted_ds[cols]

# Step 3: Reset the index of the sorted DataFrame
# `reset_index()` is used to reset the index, resulting in a default integer index starting from 0
# `drop=True` option drops the old index and prevents it from being added as a column
metros = metros.reset_index(drop=True)

# Step 4: Adjust the DataFrame index to start from 1 for display purposes
# This makes the displayed index more user-friendly and intuitive
metros.index = metros.index + 1

# Step 5: Display the first 15 rows of the DataFrame to show the metros with the highest median rents
# `head(15)` displays the top 15 rows
print(metros.head(15))
# Out:
#            Metro Area 2014 Median Rent Change since 2010
# 1        San Jose, CA           $1,706            +27.7%
# 2        Honolulu, HI           $1,447            +17.4%
# 3   San Francisco, CA           $1,445            +17.4%
# 4          Oxnard, CA           $1,422             +9.9%
# 5      Washington, DC           $1,398            +14.4%
# 6      Santa Cruz, CA           $1,370            +14.7%
# 7            Napa, CA           $1,365            +22.6%
# 8     Santa Maria, CA           $1,307            +10.5%
# 9       San Diego, CA           $1,295             +9.9%
# 10       Key West, FL           $1,266             +7.8%
# 11     Santa Rosa, CA           $1,250            +11.5%
# 12    Los Angeles, CA           $1,208             +8.5%
# 13     Bridgeport, CT           $1,168             +9.7%
# 14        Vallejo, CA           $1,161             +5.9%
# 15       New York, NY           $1,158            +11.9%

# %%
# Step 1: Sort the DataFrame `ds` to get metros with the highest median rents
# We sort by the 'median_contract_rent' column in descending order to have the highest rents at the top
# `ascending=False` ensures the sort is in descending order
sorted_ds = ds.sort_values(by='median_contract_rent', ascending=False)

# Step 2: Select only the columns defined in `cols` for the final display
# This ensures that we only keep the columns we are interested in displaying
metros = sorted_ds[cols]

# Step 3: Reset the index of the sorted DataFrame
# `reset_index()` is used to reset the index, resulting in a default integer index starting from 0
# `drop=True` option drops the old index and prevents it from being added as a column
metros = metros.reset_index(drop=True)

# Step 4: Adjust the DataFrame index to start from 1 for display purposes
# This makes the displayed index more user-friendly and intuitive
metros.index = metros.index + 1

# Step 5: Display the first 15 rows of the DataFrame to show the metros with the highest median rents
# `head(15)` displays the top 15 rows
print(metros.head(15))
# Out:
#            Metro Area 2014 Median Rent Change since 2010
# 1        San Jose, CA           $1,706            +27.7%
# 2        Honolulu, HI           $1,447            +17.4%
# 3   San Francisco, CA           $1,445            +17.4%
# 4          Oxnard, CA           $1,422             +9.9%
# 5      Washington, DC           $1,398            +14.4%
# 6      Santa Cruz, CA           $1,370            +14.7%
# 7            Napa, CA           $1,365            +22.6%
# 8     Santa Maria, CA           $1,307            +10.5%
# 9       San Diego, CA           $1,295             +9.9%
# 10       Key West, FL           $1,266             +7.8%
# 11     Santa Rosa, CA           $1,250            +11.5%
# 12    Los Angeles, CA           $1,208             +8.5%
# 13     Bridgeport, CT           $1,168             +9.7%
# 14        Vallejo, CA           $1,161             +5.9%
# 15       New York, NY           $1,158            +11.9%
